# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\lenovo\\Desktop\\FORE WORK\\12-country-vaccinations.csv")

# %%
df.head()
# Out:
#    country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Albania      ALB  1/10/2021                 0.0                0.0
# 1  Albania      ALB  1/11/2021                 NaN                NaN
# 2  Albania      ALB  1/12/2021               128.0              128.0
# 3  Albania      ALB  1/13/2021               188.0              188.0
# 4  Albania      ALB  1/14/2021               266.0              266.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN                64.0
# 2                      NaN                     NaN                64.0
# 3                      NaN                    60.0                63.0
# 4                      NaN                    78.0                66.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
df.tail()
# Out:
#      country iso_code       date  total_vaccinations  people_vaccinated  \
# 3941   Wales      NaN  2/17/2021            841975.0           822633.0
# 3942   Wales      NaN  2/18/2021            864498.0           839065.0
# 3943   Wales      NaN  2/19/2021            885906.0           853904.0
# 3944   Wales      NaN  2/20/2021            897856.0           860083.0
# 3945   Wales      NaN  2/21/2021            905000.0           862248.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 3941                  19342.0                 21636.0             22012.0
# 3942                  25433.0                 22523.0             20649.0
# 3943                  32002.0                 21408.0             18891.0
# 3944                  37773.0                 11950.0             17376.0
# 3945                  42752.0                  7144.0             16398.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
df.dtypes
# Out:
# country                                 object
# iso_code                                object
# date                                    object
# total_vaccinations                     float64
# people_vaccinated                      float64
# people_fully_vaccinated                float64
# daily_vaccinations_raw                 float64
# daily_vaccinations                     float64
# total_vaccinations_per_hundred         float64
# people_vaccinated_per_hundred          float64
# people_fully_vaccinated_per_hundred    float64
# daily_vaccinations_per_million         float64
# vaccines                                object
# source_name                             object
# source_website                          object
# dtype: object

# %%
df.shape
# Out:
# (3946, 15)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['country', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'daily_vaccinations_per_million',
#        'vaccines', 'source_name', 'source_website'],
#       dtype='object')

# %%
df.describe().round()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count              2577.0             2176.0                   1431.0
# mean            1554471.0          1358450.0                 416946.0
# std             5216082.0          4276295.0                1592756.0
# min                   0.0                0.0                      1.0
# 25%               30252.0            28101.0                   9532.0
# 50%              189349.0           175047.0                  42553.0
# 75%              753669.0           670544.0                 216372.0
# max            64177474.0         44138118.0               19438495.0
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count                  2179.0              3800.0
# mean                  72224.0             55599.0
# std                  204186.0            175051.0
# min                  -50012.0                 1.0
# 25%                    1907.0              1130.0
# ...

# %%
df.isnull().sum()
# Out:
# country                                   0
# iso_code                                284
# date                                      0
# total_vaccinations                     1369
# people_vaccinated                      1770
# people_fully_vaccinated                2515
# daily_vaccinations_raw                 1767
# daily_vaccinations                      146
# total_vaccinations_per_hundred         1369
# people_vaccinated_per_hundred          1770
# people_fully_vaccinated_per_hundred    2515
# daily_vaccinations_per_million          146
# vaccines                                  0
# source_name                               0
# source_website                            0
# dtype: int64

# %%
df
# Out:
#       country iso_code       date  total_vaccinations  people_vaccinated  \
# 0     Albania      ALB  1/10/2021                 0.0                0.0
# 1     Albania      ALB  1/11/2021                 NaN                NaN
# 2     Albania      ALB  1/12/2021               128.0              128.0
# 3     Albania      ALB  1/13/2021               188.0              188.0
# 4     Albania      ALB  1/14/2021               266.0              266.0
# ...       ...      ...        ...                 ...                ...
# 3941    Wales      NaN  2/17/2021            841975.0           822633.0
# 3942    Wales      NaN  2/18/2021            864498.0           839065.0
# 3943    Wales      NaN  2/19/2021            885906.0           853904.0
# 3944    Wales      NaN  2/20/2021            897856.0           860083.0
# 3945    Wales      NaN  2/21/2021            905000.0           862248.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
print(df['source_website'].unique())
print(df['vaccines'].unique())
print(df['country'].unique())
# Out:
# ['https://shendetesia.gov.al/covid19-ministria-e-shendetesise-1128-te-vaksinuar-3848-testime-930-te-sheruar-1071-raste-te-reja-dhe-19-humbje-jete-ne-24-oret-e-fundit/'
#  'https://www.echoroukonline.com/%d9%84%d9%82%d8%a7%d8%ad-%d9%83%d9%88%d8%b1%d9%88%d9%86%d8%a7-%d8%b9%d8%b6%d9%88-%d8%a8%d8%a7%d9%84%d9%84%d8%ac%d9%86%d8%a9-%d8%a7%d9%84%d8%b9%d9%84%d9%85%d9%8a%d8%a9-%d9%8a%d9%83%d8%b4%d9%81-%d8%b9/'
#  'https://www.govern.ad/comunicats/item/12450-els-casos-actius-per-covid-19-baixen-de-400-per-primer-cop-des-del-setembre'
#  'https://www.facebook.com/MinistryofHealthAnguilla/posts/1395958984092007?__tn__=%2CO*F'
#  'http://datos.salud.gob.ar/dataset/vacunas-contra-covid-19-dosis-aplicadas-en-la-republica-argentina'
#  'https://covidlive.com.au/vaccinations'
#  'https://info.gesundheitsministerium.gv.at/opendata/'
#  'https://eurasianet.org/azerbaijan-starts-mass-covid-19-vaccinations'
#  'https://twitter.com/MOH_Bahrain/status/1363959177241124871'
# ...

# %%
print(df['daily_vaccinations_per_million'].unique())
print(df['source_name'].unique())
# Out:
# [  nan   22.   23. ... 5992. 5511. 5201.]
# ['Ministry of Health' 'Government of Andorra'
#  'Government of Australia via covidlive.com.au' 'Government of Azerbaijan'
#  'Directorate General of Health Services' 'Sciensano'
#  'Government of Bermuda' 'Regional governments via Coronavirus Brasil'
#  'Government of Canada' 'Cayman Islands Government'
#  'Department of Statistics and Health Information'
#  'National Health Commission' 'Government of Cyprus'
#  'Statens Serum Institut' 'Ministry of Public Health'
#  'Government of Ecuador via Ecuacovid' 'Government of the United Kingdom'
#  'National Health Board' 'Government of the Faeroe Islands'
#  'Government of the Falkland Islands'
#  'Finnish Institute for Health and Welfare' 'Public Health France'
#  'Robert Koch Institut' 'Government of Gibraltar'
#  'Government of Greenland' 'Government of Guernsey'
#  'Government of Hungary' 'Directorate of Health' 'Government of Iran'
# ...

# %%
df['source_name'].value_counts()
# Out:
# Ministry of Health                              1170
# Government of the United Kingdom                 355
# National Health Commission                       118
# Government of Israel                              66
# Centers for Disease Control and Prevention        65
#                                                 ...
# Government of Australia via covidlive.com.au       8
# Ministry of Public Health                          7
# Ministry of Health, Labour and Welfare             6
# Government of Saint Helena                         1
# Government of Greenland                            1
# Name: source_name, Length: 62, dtype: int64

# %%
df['daily_vaccinations_per_million'].value_counts()
# Out:
# 43.0      56
# 4184.0    41
# 469.0     39
# 262.0     31
# 5734.0    29
#           ..
# 3355.0     1
# 422.0      1
# 6315.0     1
# 9538.0     1
# 6172.0     1
# Name: daily_vaccinations_per_million, Length: 2083, dtype: int64

# %%
df['iso_code'].value_counts()
# Out:
# GBR    71
# ISR    66
# USA    65
# BHR    62
# CHL    61
#        ..
# COL     7
# JPN     6
# NZL     3
# SHN     1
# GRL     1
# Name: iso_code, Length: 98, dtype: int64

# %%
df['source_website'].value_counts()
# Out:
# https://coronavirus.data.gov.uk/details/healthcare                                                                     355
# https://datadashboard.health.gov.il/COVID-19/general                                                                    66
# https://covid.cdc.gov/covid-data-tracker/#vaccinations                                                                  65
# https://twitter.com/MOH_Bahrain/status/1363959177241124871                                                              62
# https://www.gob.cl/yomevacuno/                                                                                          61
#                                                                                                                       ...
# https://www.facebook.com/moh.barbados/photos/a.768944336470972/3959608410737866/                                         7
# https://www.mhlw.go.jp/stf/seisakunitsuite/bunya/vaccine_sesshujisseki.html                                              6
# ...

# %%
df['country'].value_counts()
# Out:
# Wales               71
# Northern Ireland    71
# England             71
# United Kingdom      71
# Scotland            71
#                     ..
# Egypt                7
# Japan                6
# New Zealand          3
# Greenland            1
# Saint Helena         1
# Name: country, Length: 102, dtype: int64

# %%
df['date'].value_counts()
# Out:
# 2/9/2021      85
# 2/10/2021     84
# 2/13/2021     84
# 2/11/2021     84
# 2/8/2021      84
#               ..
# 12/17/2020     7
# 12/15/2020     7
# 12/18/2020     7
# 12/14/2020     5
# 12/13/2020     5
# Name: date, Length: 72, dtype: int64

# %%
pd.crosstab(df.vaccines,df.country)
# Out:
# country                                             Albania  Algeria  Andorra  \
# vaccines
# Covaxin, Oxford/AstraZeneca                               0        0        0
# Johnson&Johnson                                           0        0        0
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech              0        0        0
# Moderna, Pfizer/BioNTech                                  0        0        0
# Oxford/AstraZeneca                                        0        0        0
# Oxford/AstraZeneca, Pfizer/BioNTech                       0        0        0
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/...        0        0        0
# Oxford/AstraZeneca, Sinopharm/Beijing                     0        0        0
# Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V          0        0        0
# Oxford/AstraZeneca, Sinovac                               0        0        0
# Oxford/AstraZeneca, Sputnik V                             0        0        0
# ...

# %%
pd.crosstab(df.source_name,df.country)
# Out:
# country                                          Albania  Algeria  Andorra  \
# source_name
# COVID-19 Malta Public Health Response Team             0        0        0
# COVID-19 Vaccine Information Platform                  0        0        0
# Cayman Islands Government                              0        0        0
# Centers for Disease Control and Prevention             0        0        0
# Department of Statistics and Health Information        0        0        0
# ...                                                  ...      ...      ...
# Russian Direct Investment Fund                         0        0        0
# Saudi Health Council                                   0        0        0
# Sciensano                                              0        0        0
# Secretary of Health                                    0        0        0
# Statens Serum Institut                                 0        0        0
#
# ...

# %%
plt.figure(figsize=(30,10))
sns.countplot(y='source_name', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='source_name'>

# %%
sns.barplot(x=df['total_vaccinations'], y=df['daily_vaccinations_per_million'])
# Out:
# <AxesSubplot:xlabel='total_vaccinations', ylabel='daily_vaccinations_per_million'>

# %%
plt.figure(figsize=(5,20))
plt.scatter('people_vaccinated','country',data=df)

# %%
plt.figure(figsize=(10,5))
df1 = df.sample(400)
sns.swarmplot(x='daily_vaccinations_per_million',y='vaccines',data=df1)
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 57.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 83.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 52.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 77.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...
